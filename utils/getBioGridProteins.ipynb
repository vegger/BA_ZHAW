# %%
import pandas as pd

# %%
biogrid_df = pd.read_csv("./BIOGRID-ORGANISM-Homo_sapiens-4.4.232.tsv", sep="\t")
biogrid_df
# Out:
#            INTERACTOR_A    INTERACTOR_B OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B  \
# 0               ETG6416         ETG2318            MAP2K4              FLNC
# 1              ETG84665           ETG88              MYPN             ACTN2
# 2                 ETG90         ETG2339             ACVR1              FNTA
# 3               ETG2624         ETG5371             GATA2               PML
# 4           RP4-547C9.3         ETG6774              RPA2             STAT3
# ...                 ...             ...               ...               ...
# 1215116  XX-FW83563B9.3         ETG5430               TAZ            POLR2A
# 1215117         ETG5430  XX-FW83563B9.3            POLR2A               TAZ
# 1215118         ETG2064     OK/SW-cl.35             ERBB2            CTNNB1
# 1215119     OK/SW-cl.35         ETG2064            CTNNB1             ERBB2
# 1215120          ETG999     OK/SW-cl.35              CDH1            CTNNB1
#
# ...

# %%
uniprot_relevant_df = biogrid_df[["OFFICIAL_SYMBOL_A", "OFFICIAL_SYMBOL_B"]]
uniprot_relevant_df
# Out:
#         OFFICIAL_SYMBOL_A OFFICIAL_SYMBOL_B
# 0                  MAP2K4              FLNC
# 1                    MYPN             ACTN2
# 2                   ACVR1              FNTA
# 3                   GATA2               PML
# 4                    RPA2             STAT3
# ...                   ...               ...
# 1215116               TAZ            POLR2A
# 1215117            POLR2A               TAZ
# 1215118             ERBB2            CTNNB1
# 1215119            CTNNB1             ERBB2
# 1215120              CDH1            CTNNB1
#
# [1215121 rows x 2 columns]

# %%
to_path = "./UniProt/"
file_name = "generalProteinBinding.tsv"

# %%
uniprot_relevant_df.to_csv(to_path+file_name, sep="\t", index=False)
