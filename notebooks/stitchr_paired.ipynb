# %%
import pandas as pd
import subprocess

# %%
paired_df = pd.read_csv("../data/customDatasets/paired_concatenated.tsv", sep="\t")
paired_df
# Out:
#        TCR_name             TRAV       TRAJ        TRA_CDR3       TRBV  \
# 0             1      TRAV26-1*01  TRAJ43*01   CIVRAPGRADMRF  TRBV13*01
# 1             2        TRAV20*01  TRAJ28*01  CAVPSGAGSYQLTF  TRBV13*01
# 2             3         TRAV2*01        NaN     CAVKASGSRLT  TRBV13*01
# 3             4  TRAV38-2/DV8*01  TRAJ40*01   CAYRPPGTYKYIF  TRBV14*01
# 4             5      TRAV26-1*01  TRAJ43*01   CIVRAPGRADMRF  TRBV13*01
# ...         ...              ...        ...             ...        ...
# 29949     13697           TRAV25     TRAJ28   CAGSGAGSYQLTF        NaN
# 29950     13698           TRAV25     TRAJ28   CAGLGAGSYQLTF        NaN
# 29951     13699        TRAV17*01  TRAJ11*01  CATEGNSGYSTLTF        NaN
# 29952     13700        TRAV17*01  TRAJ11*01  CATEGDSGYSTLTF        NaN
# 29953     13701        TRAV17*01  TRAJ11*01  CASEGNSGYSTLTF        NaN
#
#              TRBJ              TRB_CDR3  TRAC  TRBC  TRA_leader  ...  \
# 0      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# 1      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN  ...
# 2      TRBJ1-5*01  CASSYEPGQVSHYSNQPQHF   NaN   NaN         NaN  ...
# 3      TRBJ2-1*01        CASSALASLNEQFF   NaN   NaN         NaN  ...
# 4      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# ...           ...                   ...   ...   ...         ...  ...
# 29949         NaN      CASSLEGQASSYEQYF   NaN   NaN         NaN  ...
# 29950         NaN      CASSLEGQGASYEQYF   NaN   NaN         NaN  ...
# 29951         NaN        CASSSQGGNYGYTF   NaN   NaN         NaN  ...
# 29952         NaN        CASSYQGGNYGYTF   NaN   NaN         NaN  ...
# 29953         NaN        CASSFQGGNYGYTF   NaN   NaN         NaN  ...
#
#        TRA_5_prime_seq  TRA_3_prime_seq  TRB_5_prime_seq  TRB_3_prime_seq  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 29949              NaN              NaN              NaN              NaN
# 29950              NaN              NaN              NaN              NaN
# 29951              NaN              NaN              NaN              NaN
# 29952              NaN              NaN              NaN              NaN
# 29953              NaN              NaN              NaN              NaN
#
#          Epitope  Score_TRA  Score_TRB     MHC A  MHC B  MHC class
# 0       FLKEKGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# 1       FLKEKGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# 2       FLKEKGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# 3       FLKEKGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# 4       FLKEQGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# ...          ...        ...        ...       ...    ...        ...
# 29949  CLGGLLTMV        NaN        NaN       NaN    NaN        NaN
# 29950  CLGGLLTMV        NaN        NaN       NaN    NaN        NaN
# 29951  FLYALALLL        NaN        NaN       NaN    NaN        NaN
# 29952  FLYALALLL        NaN        NaN       NaN    NaN        NaN
# 29953  FLYALALLL        NaN        NaN       NaN    NaN        NaN
#
# [29954 rows x 23 columns]

# %%
paired_df
# Out:
#        TCR_name             TRAV       TRAJ        TRA_CDR3       TRBV  \
# 0             1      TRAV26-1*01  TRAJ43*01   CIVRAPGRADMRF  TRBV13*01
# 1             2        TRAV20*01  TRAJ28*01  CAVPSGAGSYQLTF  TRBV13*01
# 2             3         TRAV2*01        NaN     CAVKASGSRLT  TRBV13*01
# 3             4  TRAV38-2/DV8*01  TRAJ40*01   CAYRPPGTYKYIF  TRBV14*01
# 4             5      TRAV26-1*01  TRAJ43*01   CIVRAPGRADMRF  TRBV13*01
# ...         ...              ...        ...             ...        ...
# 29949     13697           TRAV25     TRAJ28   CAGSGAGSYQLTF        NaN
# 29950     13698           TRAV25     TRAJ28   CAGLGAGSYQLTF        NaN
# 29951     13699        TRAV17*01  TRAJ11*01  CATEGNSGYSTLTF        NaN
# 29952     13700        TRAV17*01  TRAJ11*01  CATEGDSGYSTLTF        NaN
# 29953     13701        TRAV17*01  TRAJ11*01  CASEGNSGYSTLTF        NaN
#
#              TRBJ              TRB_CDR3  TRAC  TRBC  TRA_leader  ...  \
# 0      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# 1      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN  ...
# 2      TRBJ1-5*01  CASSYEPGQVSHYSNQPQHF   NaN   NaN         NaN  ...
# 3      TRBJ2-1*01        CASSALASLNEQFF   NaN   NaN         NaN  ...
# 4      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# ...           ...                   ...   ...   ...         ...  ...
# 29949         NaN      CASSLEGQASSYEQYF   NaN   NaN         NaN  ...
# 29950         NaN      CASSLEGQGASYEQYF   NaN   NaN         NaN  ...
# 29951         NaN        CASSSQGGNYGYTF   NaN   NaN         NaN  ...
# 29952         NaN        CASSYQGGNYGYTF   NaN   NaN         NaN  ...
# 29953         NaN        CASSFQGGNYGYTF   NaN   NaN         NaN  ...
#
#        TRA_5_prime_seq  TRA_3_prime_seq  TRB_5_prime_seq  TRB_3_prime_seq  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 29949              NaN              NaN              NaN              NaN
# 29950              NaN              NaN              NaN              NaN
# 29951              NaN              NaN              NaN              NaN
# 29952              NaN              NaN              NaN              NaN
# 29953              NaN              NaN              NaN              NaN
#
#          Epitope  Score_TRA  Score_TRB     MHC A  MHC B  MHC class
# 0       FLKEKGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# 1       FLKEKGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# 2       FLKEKGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# 3       FLKEKGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# 4       FLKEQGGL        2.0        2.0  HLA-B*08    B2M       MHCI
# ...          ...        ...        ...       ...    ...        ...
# 29949  CLGGLLTMV        NaN        NaN       NaN    NaN        NaN
# 29950  CLGGLLTMV        NaN        NaN       NaN    NaN        NaN
# 29951  FLYALALLL        NaN        NaN       NaN    NaN        NaN
# 29952  FLYALALLL        NaN        NaN       NaN    NaN        NaN
# 29953  FLYALALLL        NaN        NaN       NaN    NaN        NaN
#
# [29954 rows x 23 columns]

# %%
stitchr_valid_paired_df = paired_df.loc[
    paired_df["TRBV"].notna() & 
    paired_df["TRBJ"].notna() & 
    paired_df["TRAV"].notna() & 
    paired_df["TRAJ"].notna()
]

stitchr_valid_paired_df
# Out:
#        TCR_name             TRAV       TRAJ        TRA_CDR3       TRBV  \
# 0             1      TRAV26-1*01  TRAJ43*01   CIVRAPGRADMRF  TRBV13*01
# 1             2        TRAV20*01  TRAJ28*01  CAVPSGAGSYQLTF  TRBV13*01
# 3             4  TRAV38-2/DV8*01  TRAJ40*01   CAYRPPGTYKYIF  TRBV14*01
# 4             5      TRAV26-1*01  TRAJ43*01   CIVRAPGRADMRF  TRBV13*01
# 5             6        TRAV20*01  TRAJ28*01  CAVPSGAGSYQLTF  TRBV13*01
# ...         ...              ...        ...             ...        ...
# 29918     13534           TRAV16     TRAJ37  CALDGPSNTGKLIF     TRBV15
# 29919     13535           TRAV17      TRAJ7   CATDAEGNNRLAF     TRBV19
# 29920     13536           TRAV34     TRAJ13     CGAVGYQKVTF      TRBV2
# 29921     13537          TRAV8-1     TRAJ43   CAVIWYNNNDMRF    TRBV4-2
# 29922     13538          TRAV9-2     TRAJ53   CAPPRGSNYKLTF   TRBV20-1
#
#              TRBJ              TRB_CDR3  TRAC  TRBC  TRA_leader  ...  \
# 0      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# 1      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN  ...
# 3      TRBJ2-1*01        CASSALASLNEQFF   NaN   NaN         NaN  ...
# 4      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# 5      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN  ...
# ...           ...                   ...   ...   ...         ...  ...
# 29918     TRBJ2-2       CATSESSGQTYEQYF   NaN   NaN         NaN  ...
# 29919     TRBJ2-7       CASSIFGGGLGEQFF   NaN   NaN         NaN  ...
# 29920     TRBJ2-2        CALNGEISYNEQFF   NaN   NaN         NaN  ...
# 29921     TRBJ2-1        CASSQGVNTGELFF   NaN   NaN         NaN  ...
# 29922     TRBJ2-7         CSAETGLSYEQYF   NaN   NaN         NaN  ...
#
#        TRA_5_prime_seq  TRA_3_prime_seq  TRB_5_prime_seq  TRB_3_prime_seq  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# 5                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 29918              NaN              NaN              NaN              NaN
# 29919              NaN              NaN              NaN              NaN
# 29920              NaN              NaN              NaN              NaN
# 29921              NaN              NaN              NaN              NaN
# 29922              NaN              NaN              NaN              NaN
#
#          Epitope  Score_TRA  Score_TRB      MHC A      MHC B  MHC class
# 0       FLKEKGGL        2.0        2.0   HLA-B*08        B2M       MHCI
# 1       FLKEKGGL        2.0        2.0   HLA-B*08        B2M       MHCI
# 3       FLKEKGGL        2.0        2.0   HLA-B*08        B2M       MHCI
# 4       FLKEQGGL        2.0        2.0   HLA-B*08        B2M       MHCI
# 5       FLKEQGGL        2.0        2.0   HLA-B*08        B2M       MHCI
# ...          ...        ...        ...        ...        ...        ...
# 29918  FLCMKALLL        NaN        NaN  HLA-A2:01  HLA-A2:01       MHCI
# 29919  FLCMKALLL        NaN        NaN  HLA-A2:01  HLA-A2:01       MHCI
# 29920  FLCMKALLL        NaN        NaN  HLA-A2:01  HLA-A2:01       MHCI
# 29921  FLCMKALLL        NaN        NaN  HLA-A2:01  HLA-A2:01       MHCI
# 29922  FLCMKALLL        NaN        NaN  HLA-A2:01  HLA-A2:01       MHCI
#
# [27878 rows x 23 columns]

# %%
# List of columns you want to exclude => because not included in Stitchr template
excluded_columns = ["Epitope", "Score_TRA", "Score_TRB", "MHC A", "MHC B", "MHC class"]

stitchr_paired_df = stitchr_valid_paired_df.drop(columns=excluded_columns)
stitchr_paired_df
# Out:
#        TCR_name             TRAV       TRAJ        TRA_CDR3       TRBV  \
# 0             1      TRAV26-1*01  TRAJ43*01   CIVRAPGRADMRF  TRBV13*01
# 1             2        TRAV20*01  TRAJ28*01  CAVPSGAGSYQLTF  TRBV13*01
# 3             4  TRAV38-2/DV8*01  TRAJ40*01   CAYRPPGTYKYIF  TRBV14*01
# 4             5      TRAV26-1*01  TRAJ43*01   CIVRAPGRADMRF  TRBV13*01
# 5             6        TRAV20*01  TRAJ28*01  CAVPSGAGSYQLTF  TRBV13*01
# ...         ...              ...        ...             ...        ...
# 29918     13534           TRAV16     TRAJ37  CALDGPSNTGKLIF     TRBV15
# 29919     13535           TRAV17      TRAJ7   CATDAEGNNRLAF     TRBV19
# 29920     13536           TRAV34     TRAJ13     CGAVGYQKVTF      TRBV2
# 29921     13537          TRAV8-1     TRAJ43   CAVIWYNNNDMRF    TRBV4-2
# 29922     13538          TRAV9-2     TRAJ53   CAPPRGSNYKLTF   TRBV20-1
#
#              TRBJ              TRB_CDR3  TRAC  TRBC  TRA_leader  TRB_leader  \
# 0      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN         NaN
# 1      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN         NaN
# 3      TRBJ2-1*01        CASSALASLNEQFF   NaN   NaN         NaN         NaN
# 4      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN         NaN
# 5      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN         NaN
# ...           ...                   ...   ...   ...         ...         ...
# 29918     TRBJ2-2       CATSESSGQTYEQYF   NaN   NaN         NaN         NaN
# 29919     TRBJ2-7       CASSIFGGGLGEQFF   NaN   NaN         NaN         NaN
# 29920     TRBJ2-2        CALNGEISYNEQFF   NaN   NaN         NaN         NaN
# 29921     TRBJ2-1        CASSQGVNTGELFF   NaN   NaN         NaN         NaN
# 29922     TRBJ2-7         CSAETGLSYEQYF   NaN   NaN         NaN         NaN
#
#        Linker  Link_order  TRA_5_prime_seq  TRA_3_prime_seq  TRB_5_prime_seq  \
# 0         NaN         NaN              NaN              NaN              NaN
# 1         NaN         NaN              NaN              NaN              NaN
# 3         NaN         NaN              NaN              NaN              NaN
# 4         NaN         NaN              NaN              NaN              NaN
# 5         NaN         NaN              NaN              NaN              NaN
# ...       ...         ...              ...              ...              ...
# 29918     NaN         NaN              NaN              NaN              NaN
# 29919     NaN         NaN              NaN              NaN              NaN
# 29920     NaN         NaN              NaN              NaN              NaN
# 29921     NaN         NaN              NaN              NaN              NaN
# 29922     NaN         NaN              NaN              NaN              NaN
#
#        TRB_3_prime_seq
# 0                  NaN
# 1                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# ...                ...
# 29918              NaN
# 29919              NaN
# 29920              NaN
# 29921              NaN
# 29922              NaN
#
# [27878 rows x 17 columns]

# %%
file_path = "../data/customDatasets/temp/"
file_name = "Stitchr_paired_concatenated.tsv"
stitchr_paired_df.to_csv(file_path+file_name, sep="\t", index=False)

# %%
from_paired_path = file_path+file_name
to_paired_path =  "../data/customDatasets/Stitchr_paired_concatenated"
command = ['thimble', '-in', from_paired_path, '-r', 'AB', "-s", "HUMAN", "-o", to_paired_path]

# %%
result = subprocess.run(command, capture_output=True, text=True)

# Check if the command was executed successfully
if result.returncode == 0:
    print("Command executed successfully.")
    # If you want to print the output
    print("Output:", result.stdout)
else:
    print("Error in command execution.")
    # If you want to print the error
    print("Error:", result.stderr)
# Out:
# Command executed successfully.
# Output: Took 23.53 seconds

# %% [markdown]
# ## add the removed columns ("Epitope", "Score_TRA", "Score_TRB", "MHC A", "MHC B", "MHC class") back to the dataframe and store it again. Before doing so handle the error prune entries!!!
#
# => take the removed columns from stitchr_valid_paired_df
