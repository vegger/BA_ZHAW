# %%
import pandas as pd
import subprocess

# %%
paired_df = pd.read_csv("../data/customDatasets/paired_concatenated.tsv", sep="\t")
paired_df
# Out:
#        TCR_name             TRAV       TRAJ          TRA_CDR3        TRBV  \
# 0             1      TRAV26-1*01  TRAJ43*01     CIVRAPGRADMRF   TRBV13*01
# 1             2        TRAV20*01  TRAJ28*01    CAVPSGAGSYQLTF   TRBV13*01
# 2             3         TRAV2*01        NaN     CCAVKASGSRLTF   TRBV13*01
# 3             4  TRAV38-2/DV8*01  TRAJ40*01     CAYRPPGTYKYIF   TRBV14*01
# 4             5      TRAV26-1*01  TRAJ43*01     CIVRAPGRADMRF   TRBV13*01
# ...         ...              ...        ...               ...         ...
# 39147     39148       TRAV29/DV5     TRAJ52       CAARVRGKLTF     TRBV7-6
# 39148     39149            TRAV6     TRAJ42    CAPEWGGSQGNLIF     TRBV4-2
# 39149     39150          TRAV8-3     TRAJ10  CAVDPILTGGGNKLTF      TRBV27
# 39150     39151       TRAV9-2*01  TRAJ40*01    CALSHYSGTYKYIF  TRBV6-1*01
# 39151     39152         TRAV13-2     TRAJ53    CAENSGGSNYKLTF     TRBV5-4
#
#              TRBJ              TRB_CDR3  TRAC  TRBC  TRA_leader  ...  \
# 0      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# 1      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN  ...
# 2      TRBJ1-5*01  CASSYEPGQVSHYSNQPQHF   NaN   NaN         NaN  ...
# 3      TRBJ2-1*01        CASSALASLNEQFF   NaN   NaN         NaN  ...
# 4      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# ...           ...                   ...   ...   ...         ...  ...
# 39147     TRBJ2-2  CASSLVSEIGGSTNTGELFF   NaN   NaN         NaN  ...
# 39148     TRBJ1-5        CASSQDVRGQPQHF   NaN   NaN         NaN  ...
# 39149     TRBJ2-1       CASSLKRETYNEQFF   NaN   NaN         NaN  ...
# 39150  TRBJ1-2*01         CASSEGTDYGYTF   NaN   NaN         NaN  ...
# 39151     TRBJ1-1         CASSWERAGKAFF   NaN   NaN         NaN  ...
#
#        TRA_5_prime_seq  TRA_3_prime_seq  TRB_5_prime_seq  TRB_3_prime_seq  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 39147              NaN              NaN              NaN              NaN
# 39148              NaN              NaN              NaN              NaN
# 39149              NaN              NaN              NaN              NaN
# 39150              NaN              NaN              NaN              NaN
# 39151              NaN              NaN              NaN              NaN
#
#                     Epitope  Score           MHC A           MHC B  MHC class  \
# 0                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 1                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 2                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 3                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 4                  FLKEQGGL    2.0        HLA-B*08             B2M       MHCI
# ...                     ...    ...             ...             ...        ...
# 39147       GTRVIRDMTLHSAPS    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39148       GTRVIRDMTLHSAPS    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39149           AGILARNLVPM    NaN             NaN  HLA-DRB3*02:02      MHCII
# 39150           RTAMFQDPQER    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39151  MTEYKLVVVGAVGVGKSALT    NaN             NaN  HLA-DRB5*01:01      MHCII
#
#       Binding
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 39147       1
# 39148       1
# 39149       1
# 39150       1
# 39151       1
#
# [39152 rows x 23 columns]

# %%
paired_df
# Out:
#        TCR_name             TRAV       TRAJ          TRA_CDR3        TRBV  \
# 0             1      TRAV26-1*01  TRAJ43*01     CIVRAPGRADMRF   TRBV13*01
# 1             2        TRAV20*01  TRAJ28*01    CAVPSGAGSYQLTF   TRBV13*01
# 2             3         TRAV2*01        NaN     CCAVKASGSRLTF   TRBV13*01
# 3             4  TRAV38-2/DV8*01  TRAJ40*01     CAYRPPGTYKYIF   TRBV14*01
# 4             5      TRAV26-1*01  TRAJ43*01     CIVRAPGRADMRF   TRBV13*01
# ...         ...              ...        ...               ...         ...
# 39147     39148       TRAV29/DV5     TRAJ52       CAARVRGKLTF     TRBV7-6
# 39148     39149            TRAV6     TRAJ42    CAPEWGGSQGNLIF     TRBV4-2
# 39149     39150          TRAV8-3     TRAJ10  CAVDPILTGGGNKLTF      TRBV27
# 39150     39151       TRAV9-2*01  TRAJ40*01    CALSHYSGTYKYIF  TRBV6-1*01
# 39151     39152         TRAV13-2     TRAJ53    CAENSGGSNYKLTF     TRBV5-4
#
#              TRBJ              TRB_CDR3  TRAC  TRBC  TRA_leader  ...  \
# 0      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# 1      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN  ...
# 2      TRBJ1-5*01  CASSYEPGQVSHYSNQPQHF   NaN   NaN         NaN  ...
# 3      TRBJ2-1*01        CASSALASLNEQFF   NaN   NaN         NaN  ...
# 4      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# ...           ...                   ...   ...   ...         ...  ...
# 39147     TRBJ2-2  CASSLVSEIGGSTNTGELFF   NaN   NaN         NaN  ...
# 39148     TRBJ1-5        CASSQDVRGQPQHF   NaN   NaN         NaN  ...
# 39149     TRBJ2-1       CASSLKRETYNEQFF   NaN   NaN         NaN  ...
# 39150  TRBJ1-2*01         CASSEGTDYGYTF   NaN   NaN         NaN  ...
# 39151     TRBJ1-1         CASSWERAGKAFF   NaN   NaN         NaN  ...
#
#        TRA_5_prime_seq  TRA_3_prime_seq  TRB_5_prime_seq  TRB_3_prime_seq  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 39147              NaN              NaN              NaN              NaN
# 39148              NaN              NaN              NaN              NaN
# 39149              NaN              NaN              NaN              NaN
# 39150              NaN              NaN              NaN              NaN
# 39151              NaN              NaN              NaN              NaN
#
#                     Epitope  Score           MHC A           MHC B  MHC class  \
# 0                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 1                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 2                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 3                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 4                  FLKEQGGL    2.0        HLA-B*08             B2M       MHCI
# ...                     ...    ...             ...             ...        ...
# 39147       GTRVIRDMTLHSAPS    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39148       GTRVIRDMTLHSAPS    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39149           AGILARNLVPM    NaN             NaN  HLA-DRB3*02:02      MHCII
# 39150           RTAMFQDPQER    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39151  MTEYKLVVVGAVGVGKSALT    NaN             NaN  HLA-DRB5*01:01      MHCII
#
#       Binding
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 39147       1
# 39148       1
# 39149       1
# 39150       1
# 39151       1
#
# [39152 rows x 23 columns]

# %%
stitchr_valid_paired_df = paired_df.loc[
    paired_df["TRBV"].notna() & 
    paired_df["TRBJ"].notna() & 
    paired_df["TRAV"].notna() & 
    paired_df["TRAJ"].notna()
]

stitchr_valid_paired_df
# Out:
#        TCR_name             TRAV       TRAJ          TRA_CDR3        TRBV  \
# 0             1      TRAV26-1*01  TRAJ43*01     CIVRAPGRADMRF   TRBV13*01
# 1             2        TRAV20*01  TRAJ28*01    CAVPSGAGSYQLTF   TRBV13*01
# 3             4  TRAV38-2/DV8*01  TRAJ40*01     CAYRPPGTYKYIF   TRBV14*01
# 4             5      TRAV26-1*01  TRAJ43*01     CIVRAPGRADMRF   TRBV13*01
# 5             6        TRAV20*01  TRAJ28*01    CAVPSGAGSYQLTF   TRBV13*01
# ...         ...              ...        ...               ...         ...
# 39147     39148       TRAV29/DV5     TRAJ52       CAARVRGKLTF     TRBV7-6
# 39148     39149            TRAV6     TRAJ42    CAPEWGGSQGNLIF     TRBV4-2
# 39149     39150          TRAV8-3     TRAJ10  CAVDPILTGGGNKLTF      TRBV27
# 39150     39151       TRAV9-2*01  TRAJ40*01    CALSHYSGTYKYIF  TRBV6-1*01
# 39151     39152         TRAV13-2     TRAJ53    CAENSGGSNYKLTF     TRBV5-4
#
#              TRBJ              TRB_CDR3  TRAC  TRBC  TRA_leader  ...  \
# 0      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# 1      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN  ...
# 3      TRBJ2-1*01        CASSALASLNEQFF   NaN   NaN         NaN  ...
# 4      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN  ...
# 5      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN  ...
# ...           ...                   ...   ...   ...         ...  ...
# 39147     TRBJ2-2  CASSLVSEIGGSTNTGELFF   NaN   NaN         NaN  ...
# 39148     TRBJ1-5        CASSQDVRGQPQHF   NaN   NaN         NaN  ...
# 39149     TRBJ2-1       CASSLKRETYNEQFF   NaN   NaN         NaN  ...
# 39150  TRBJ1-2*01         CASSEGTDYGYTF   NaN   NaN         NaN  ...
# 39151     TRBJ1-1         CASSWERAGKAFF   NaN   NaN         NaN  ...
#
#        TRA_5_prime_seq  TRA_3_prime_seq  TRB_5_prime_seq  TRB_3_prime_seq  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# 5                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 39147              NaN              NaN              NaN              NaN
# 39148              NaN              NaN              NaN              NaN
# 39149              NaN              NaN              NaN              NaN
# 39150              NaN              NaN              NaN              NaN
# 39151              NaN              NaN              NaN              NaN
#
#                     Epitope  Score           MHC A           MHC B  MHC class  \
# 0                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 1                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 3                  FLKEKGGL    2.0        HLA-B*08             B2M       MHCI
# 4                  FLKEQGGL    2.0        HLA-B*08             B2M       MHCI
# 5                  FLKEQGGL    2.0        HLA-B*08             B2M       MHCI
# ...                     ...    ...             ...             ...        ...
# 39147       GTRVIRDMTLHSAPS    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39148       GTRVIRDMTLHSAPS    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39149           AGILARNLVPM    NaN             NaN  HLA-DRB3*02:02      MHCII
# 39150           RTAMFQDPQER    NaN  HLA-DQA1*01:02             NaN      MHCII
# 39151  MTEYKLVVVGAVGVGKSALT    NaN             NaN  HLA-DRB5*01:01      MHCII
#
#       Binding
# 0           1
# 1           1
# 3           1
# 4           1
# 5           1
# ...       ...
# 39147       1
# 39148       1
# 39149       1
# 39150       1
# 39151       1
#
# [37075 rows x 23 columns]

# %%
# List of columns you want to exclude => because not included in Stitchr template
excluded_columns = ["Epitope", "Score", "MHC A", "MHC B", "MHC class"]

stitchr_paired_df = stitchr_valid_paired_df.drop(columns=excluded_columns)
stitchr_paired_df
# Out:
#        TCR_name             TRAV       TRAJ          TRA_CDR3        TRBV  \
# 0             1      TRAV26-1*01  TRAJ43*01     CIVRAPGRADMRF   TRBV13*01
# 1             2        TRAV20*01  TRAJ28*01    CAVPSGAGSYQLTF   TRBV13*01
# 3             4  TRAV38-2/DV8*01  TRAJ40*01     CAYRPPGTYKYIF   TRBV14*01
# 4             5      TRAV26-1*01  TRAJ43*01     CIVRAPGRADMRF   TRBV13*01
# 5             6        TRAV20*01  TRAJ28*01    CAVPSGAGSYQLTF   TRBV13*01
# ...         ...              ...        ...               ...         ...
# 39147     39148       TRAV29/DV5     TRAJ52       CAARVRGKLTF     TRBV7-6
# 39148     39149            TRAV6     TRAJ42    CAPEWGGSQGNLIF     TRBV4-2
# 39149     39150          TRAV8-3     TRAJ10  CAVDPILTGGGNKLTF      TRBV27
# 39150     39151       TRAV9-2*01  TRAJ40*01    CALSHYSGTYKYIF  TRBV6-1*01
# 39151     39152         TRAV13-2     TRAJ53    CAENSGGSNYKLTF     TRBV5-4
#
#              TRBJ              TRB_CDR3  TRAC  TRBC  TRA_leader  TRB_leader  \
# 0      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN         NaN
# 1      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN         NaN
# 3      TRBJ2-1*01        CASSALASLNEQFF   NaN   NaN         NaN         NaN
# 4      TRBJ1-5*01  CASSYLPGQGDHYSNQPQHF   NaN   NaN         NaN         NaN
# 5      TRBJ1-5*01   CASSFEPGQGFYSNQPQHF   NaN   NaN         NaN         NaN
# ...           ...                   ...   ...   ...         ...         ...
# 39147     TRBJ2-2  CASSLVSEIGGSTNTGELFF   NaN   NaN         NaN         NaN
# 39148     TRBJ1-5        CASSQDVRGQPQHF   NaN   NaN         NaN         NaN
# 39149     TRBJ2-1       CASSLKRETYNEQFF   NaN   NaN         NaN         NaN
# 39150  TRBJ1-2*01         CASSEGTDYGYTF   NaN   NaN         NaN         NaN
# 39151     TRBJ1-1         CASSWERAGKAFF   NaN   NaN         NaN         NaN
#
#        Linker  Link_order  TRA_5_prime_seq  TRA_3_prime_seq  TRB_5_prime_seq  \
# 0         NaN         NaN              NaN              NaN              NaN
# 1         NaN         NaN              NaN              NaN              NaN
# 3         NaN         NaN              NaN              NaN              NaN
# 4         NaN         NaN              NaN              NaN              NaN
# 5         NaN         NaN              NaN              NaN              NaN
# ...       ...         ...              ...              ...              ...
# 39147     NaN         NaN              NaN              NaN              NaN
# 39148     NaN         NaN              NaN              NaN              NaN
# 39149     NaN         NaN              NaN              NaN              NaN
# 39150     NaN         NaN              NaN              NaN              NaN
# 39151     NaN         NaN              NaN              NaN              NaN
#
#        TRB_3_prime_seq  Binding
# 0                  NaN        1
# 1                  NaN        1
# 3                  NaN        1
# 4                  NaN        1
# 5                  NaN        1
# ...                ...      ...
# 39147              NaN        1
# 39148              NaN        1
# 39149              NaN        1
# 39150              NaN        1
# 39151              NaN        1
#
# [37075 rows x 18 columns]

# %%
stitchr_paired_df = stitchr_paired_df.drop(columns=["Binding"])
stitchr_paired_df.columns
# Out:
# Index(['TCR_name', 'TRAV', 'TRAJ', 'TRA_CDR3', 'TRBV', 'TRBJ', 'TRB_CDR3',
#        'TRAC', 'TRBC', 'TRA_leader', 'TRB_leader', 'Linker', 'Link_order',
#        'TRA_5_prime_seq', 'TRA_3_prime_seq', 'TRB_5_prime_seq',
#        'TRB_3_prime_seq'],
#       dtype='object')

# %%
file_path = "../data/customDatasets/temp/"
file_name = "Stitchr_ready_paired_concatenated.tsv"
stitchr_paired_df.to_csv(file_path+file_name, sep="\t", index=False)

# %%
from_paired_path = file_path+file_name
to_paired_path =  "../data/customDatasets/temp/plain_Stitchr_paired_concatenated"
command = ['thimble', '-in', from_paired_path, '-r', 'AB', "-s", "HUMAN", "-o", to_paired_path]

# %%
result = subprocess.run(command, capture_output=True, text=True)

# Check if the command was executed successfully
if result.returncode == 0:
    print("Command executed successfully.")
    # If you want to print the output
    print("Output:", result.stdout)
else:
    print("Error in command execution.")
    # If you want to print the error
    print("Error:", result.stderr)
# Out:
# Command executed successfully.
# Output: Took 34.02 seconds

# %%
after_stitchr_df = pd.read_csv(to_paired_path+".tsv", sep="\t")

# %%
stitchr_valid_paired_df.columns
# Out:
# Index(['TCR_name', 'TRAV', 'TRAJ', 'TRA_CDR3', 'TRBV', 'TRBJ', 'TRB_CDR3',
#        'TRAC', 'TRBC', 'TRA_leader', 'TRB_leader', 'Linker', 'Link_order',
#        'TRA_5_prime_seq', 'TRA_3_prime_seq', 'TRB_5_prime_seq',
#        'TRB_3_prime_seq', 'Epitope', 'Score', 'MHC A', 'MHC B', 'MHC class',
#        'Binding'],
#       dtype='object')

# %%
after_stitchr_df["Epitope"] = stitchr_valid_paired_df["Epitope"]
after_stitchr_df["Score"] = stitchr_valid_paired_df["Score"]
after_stitchr_df["MHC A"] = stitchr_valid_paired_df["MHC A"]
after_stitchr_df["MHC B"] = stitchr_valid_paired_df["MHC B"]
after_stitchr_df["MHC class"] = stitchr_valid_paired_df["MHC class"]
after_stitchr_df["Binding"] = stitchr_valid_paired_df["Binding"]

after_stitchr_df.columns
# Out:
# Index(['TCR_name', 'TRA_nt', 'TRB_nt', 'TRA_aa', 'TRB_aa', 'TRAV', 'TRAJ',
#        'TRA_CDR3', 'TRBV', 'TRBJ', 'TRB_CDR3', 'TRAC', 'TRBC', 'TRA_leader',
#        'TRB_leader', 'Linker', 'Link_order', 'TRA_5_prime_seq',
#        'TRA_3_prime_seq', 'TRB_5_prime_seq', 'TRB_3_prime_seq', 'Linked_nt',
#        'Linked_aa', 'Warnings/Errors', 'Epitope', 'Score', 'MHC A', 'MHC B',
#        'MHC class', 'Binding'],
#       dtype='object')

# %%
after_stitchr_df.to_csv("../data/customDatasets/Stitchr_paired_concatenated.tsv", sep="\t", index=False)
