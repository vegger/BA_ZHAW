# %%
import pandas as pd
import numpy as np
import peptides

# %%
train_paired_epitope_gene_physico = np.load("/teamspace/studios/this_studio/BA/physico/train_paired_epitope_gene_physico.npz", allow_pickle=True)
train_paired_TRA_gene_physico = np.load("/teamspace/studios/this_studio/BA/physico/train_paired_TRA_gene_physico.npz", allow_pickle=True)
train_paired_TRB_gene_physico = np.load("/teamspace/studios/this_studio/BA/physico/train_paired_TRB_gene_physico.npz", allow_pickle=True)

# %%
print(train_paired_epitope_gene_physico.keys())
# Out:
# KeysView(NpzFile '/teamspace/studios/this_studio/BA/physico/train_paired_epitope_gene_physico.npz' with keys: ELAGIGILTA, LLWNGPMAV, MEVTPSGTWL, NNILIATCV, YLEPGPVTV...)

# %%
train_paired_epitope_gene_physico["NNILIATCV"]
# Out:
# array([-3.6111110e-01, -7.4111110e-01, -9.5555559e-02,  3.8555557e-01,
#         6.2222224e-02,  2.4888889e-01, -6.4444445e-02, -2.4444444e-01,
#        -1.8222222e-01,  1.1333334e-01, -3.6111110e-01, -3.8999999e-01,
#         1.8888889e-02,  2.3000000e-01,  1.3988888e-01, -1.7155555e-01,
#         3.6133334e-01, -1.9800000e-01,  1.1333334e-01, -2.3777778e-01,
#        -4.9222222e-01,  6.4777780e-01, -2.3444444e-01, -2.7888888e-01,
#        -2.4444444e-02, -4.3333333e-02,  9.5555559e-02,  4.7666666e-01,
#        -5.1444447e-01, -5.8333331e-01,  5.4222220e-01, -4.8222223e-01,
#        -8.8111110e-02,  9.1888890e-02, -9.0444446e-02, -2.5555555e-02,
#        -9.8222226e-02, -7.1666664e-01, -4.8111111e-01,  1.8577778e+00,
#        -1.8133334e+00, -1.1144445e+00,  5.9666669e-01,  4.5333335e-01,
#        -1.7222223e-01,  7.3333335e-01, -4.6888888e-01,  2.5022224e-01,
#         8.2888886e-02, -1.0388889e-01, -1.0666667e-02, -1.0215555e+00,
# ...

# %%
peptide1_Peptide = peptides.Peptide("NNILIATCV")
peptide1_Peptide.descriptors()
# Out:
# {'BLOSUM1': -0.3611111111111111,
#  'BLOSUM2': -0.741111111111111,
#  'BLOSUM3': -0.09555555555555557,
#  'BLOSUM4': 0.3855555555555556,
#  'BLOSUM5': 0.06222222222222224,
#  'BLOSUM6': 0.2488888888888889,
#  'BLOSUM7': -0.06444444444444444,
#  'BLOSUM8': -0.24444444444444446,
#  'BLOSUM9': -0.1822222222222222,
#  'BLOSUM10': 0.11333333333333334,
#  'PP1': -0.3611111111111111,
#  'PP2': -0.39,
#  'PP3': 0.018888888888888893,
#  'F1': 0.23000000000000004,
#  'F2': 0.13988888888888887,
#  'F3': -0.17155555555555552,
#  'F4': 0.3613333333333333,
#  'F5': -0.198,
#  'F6': 0.11333333333333334,
#  'KF1': -0.23777777777777784,
#  'KF2': -0.49222222222222217,
#  'KF3': 0.6477777777777778,
#  'KF4': -0.23444444444444443,
#  'KF5': -0.2788888888888889,
#  'KF6': -0.024444444444444442,
#  'KF7': -0.04333333333333335,
#  'KF8': 0.09555555555555556,
#  'KF9': 0.4766666666666667,
#  'KF10': -0.5144444444444444,
#  'MSWHIM1': -0.5833333333333334,
#  'MSWHIM2': 0.5422222222222222,
# ...

# %% [markdown]
# As one can see they are the same whihc indicates, that the physicos are computed correctly!
